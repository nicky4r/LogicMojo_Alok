# %% [markdown]
# # My 1st python code: Hello world
# print ("Hello world, this is my 1st python code")

# %%
print ("Hello world, this is my 1st python Code")
# Out:
# Hello world, this is my 1st python Code

# %%
print("Hello Alok")
print("How r u")
# Out:
# Hello Alok
# How r u

# %% [markdown]
# ## print() function in python

# %%
print ("My name is Alok", end= '\t''\t') #\t is used for tab space
print ("I am student of LogicMojo")
# Out:
# My name is Alok		I am student of LogicMojo
